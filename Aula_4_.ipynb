# %% [markdown]
# <a href="https://colab.research.google.com/github/victor9910vhv-sys/Programacao/blob/main/Aula_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ATIVIDADE:**
#
# Escrever um programa que recebe a temperatura em graus celsius e converte para Fahrenheit
#
# ## Entrada: graus celsíus
#
# ## Processamento
# F = C * (9/5) + 32
#
# ## Saída
#
# mostrar graus em Fahrenheit

# %%
#Calcular a área do retângulo

#Entrada

comprimento = float (input ("digite o comprimento: "))
altura = float (input ("digite a altura: "))

#Processamento

area = comprimento * altura

#Saída

print (f"O total da área do retângulo e igual: {area}")
# Out:
# ite o comprimento: 353
# digite a altura: 353
# O total da área do retângulo e igual: 124609.0

# %%
# Escrever um prpograma que faça cálculos aritméticos

# Entrada

a = int (input("digite o primeiro número: "))
b = int (input("digite o segundo número: "))

# Processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b # Usar barra dupla "//" para divisões inteira
resto = a % b # o símbolo de % ao resto da divisão

#Saída

print (" |--------------------CALCULADORA SIMPLES----------------------|")
print (" |                                                             |")
print (" |-----------------------------SOMA----------------------------|")
print (" |                                                             |")
print (f"O resultado da soma de {a} mais {b} é igual: {soma}")
print ("")
print (" |---------------------------SUBTRAÇÃO-------------------------|")
print ("")
print (f"O resultado da subtração de {a} menos {b} é igual: {subtracao}")
print ("")
print (" |-------------------------MULTIPLICAÇÃO-----------------------|")
print ("")
print (f"O resultado da multiplicação de {a} vezes {b} é igual: {multiplicacao}")
print ("")
print ("| ----------------------------DIVISÃO------------------------ -|")
print ("|                                                              |")
print (f"O resultado da divisão de {a} dividido {b} é igual: {divisao}")
# Out:
# digite o primeiro número: 6
# digite o segundo número: 6
#  |--------------------CALCULADORA SIMPLES----------------------|
#  |                                                             |
#  |-----------------------------SOMA----------------------------|
#  |                                                             |
# O resultado da soma de 6 mais 6 é igual: 12
#
#  |---------------------------SUBTRAÇÃO-------------------------|
#
# O resultado da subtração de 6 menos 6 é igual: 0
#
#  |-------------------------MULTIPLICAÇÃO-----------------------|
#
# O resultado da multiplicação de 6 vezes 6 é igual: 36
#
# | ----------------------------DIVISÃO------------------------ -|
#
# O resultado da divisão de 6 dividido 6 é igual: 1.0
# |                                                              |
